# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold,GridSearchCV
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# %% [markdown]
# 二、特征工程

# %%
def get_features(data):
    # 用众数填充年龄为0的数据
    data.loc[data['用户年龄']==0,'用户年龄'] = data['用户年龄'].mode() 
    # 两个重要性比较高的特征
    data['相对网龄'] = data['用户网龄（月）']/data['用户年龄']
    data['网龄年龄差'] = data['用户年龄'] - data['用户网龄（月）']/12
    
    # 构造一些特征
    data['缴费金额能否覆盖当月账单'] = data['缴费用户最近一次缴费金额（元）']-data['用户账单当月总费用（元）']
    data['最近一次交费是否超过平均消费额'] = data['缴费用户最近一次缴费金额（元）']-data['用户近6个月平均消费值（元）']
    data['当月账单是否超过平均消费额'] = data['用户账单当月总费用（元）']-data['用户近6个月平均消费值（元）']
    
    data['通话人均花费'] = data['用户账单当月总费用（元）'] / (data['当月通话交往圈人数']+1)
    
    data['近半年账单'] = data['用户近6个月平均消费值（元）']*6 + data['用户账单当月总费用（元）']
    
    
    data['是否去过高档商场'] = data['当月是否逛过福州仓山万达'] + data['当月是否到过福州山姆会员店']
    data['是否去过高档商场'] = data['是否去过高档商场'].map(lambda x: 1 if x>=1 else 0)

        
    # 相乘组合特征
    data['是否商场_旅游'] = data['是否去过高档商场'] * data['当月是否景点游览']
    data['是否商场_体育馆'] = data['是否去过高档商场'] * data['当月是否体育场馆消费']
    data['是否商场_电影'] = data['是否去过高档商场'] * data['当月是否看电影'] 
    data['是否体育馆_旅游'] = data['当月是否体育场馆消费'] * data['当月是否景点游览']
    data['是否电影_旅游'] = data['当月是否看电影'] * data['当月是否景点游览']
    data['是否电影_体育馆'] = data['当月是否看电影'] * data['当月是否体育场馆消费']    
    
    data['是否商场_旅游_体育馆'] = data['是否去过高档商场'] * data['当月是否景点游览'] * data['当月是否体育场馆消费']
    data['是否商场_电影_体育馆'] = data['是否去过高档商场'] * data['当月是否看电影'] * data['当月是否体育场馆消费']
    data['是否商场_电影_旅游'] = data['是否去过高档商场'] * data['当月是否看电影'] * data['当月是否景点游览']
    data['是否体育馆_电影_旅游'] = data['当月是否体育场馆消费'] * data['当月是否看电影'] * data['当月是否景点游览']
    
    data['是否商场_体育馆_电影_旅游'] = data['是否去过高档商场']*data['当月是否体育场馆消费']*data['当月是否看电影']*data['当月是否景点游览']
       
    
    # 把这些连续的特征离散化
    data['交通类应用使用次数'] = data['当月飞机类应用使用次数'] + data['当月火车类应用使用次数']
    
    discrete_features = ['交通类应用使用次数','当月物流快递类应用使用次数','当月飞机类应用使用次数',
                         '当月火车类应用使用次数','当月旅游资讯类应用使用次数']
    
    def map_discrete(x):
        if x == 0:
            return 0
        elif x <= 5:
            return 1
        elif x<=15:
            return 2
        elif x <=50:
            return 3
        elif x <= 100:
            return 4
        else:
            return 5
        
    for col in discrete_features:
        data[col] = data[col].map(lambda x:map_discrete(x))
        
    return data

# %%
# 对数据的基本的处理（预处理）
def base_process(data):
    transform_features = ['相对网龄','网龄年龄差','用户年龄','用户网龄（月）','当月通话交往圈人数',
        '最近一次交费是否超过平均消费额','近三个月月均商场出现次数','当月网购类应用使用次数',
        '当月物流快递类应用使用次数','当月账单是否超过平均消费额','当月金融理财类应用使用总次数',
        '当月视频播放类应用使用次数','当月飞机类应用使用次数','当月火车类应用使用次数',
        '当月旅游资讯类应用使用次数','近半年账单','通话人均花费']
    
    
    user_bill_features = [ '缴费用户最近一次缴费金额（元）', '用户近6个月平均消费值（元）',
                        '用户账单当月总费用（元）', '用户当月账户余额（元）']
    
    log_features = ['当月网购类应用使用次数','当月金融理财类应用使用总次数',
        '当月视频播放类应用使用次数']
    
    for col in transform_features + user_bill_features + log_features:
        up_limit = np.percentile(data[col].values,99.9)
        down_limit = np.percentile(data[col].values,0.1)
        data[col].loc[data[col] > up_limit] = up_limit
        data[col].loc[data[col] < down_limit] = down_limit
            
    # 对数化，x 变成 log（1+x）
    for col in user_bill_features + log_features:
        data[col] = data[col].map(lambda x : np.log1p(x))
    # loc 按索引值定位；iloc 按索引位置定位
        
    train,test = data[:50000],data[50000:]
    return train,test

# %%
def load_data():
    train = pd.read_csv('G:/Jupyter_program/Algorithm/DCIC/train_dataset.csv')
    label = train['信用分'].values
    del train['信用分']
    
    test = pd.read_csv('G:/Jupyter_program/Algorithm/DCIC/test_dataset.csv')
    test_id = test['用户编码'].values
    
    data = pd.concat([train,test],axis=0,ignore_index=True)
    del data['用户编码']
    
    return data,label,test_id

# %% [markdown]
# 三、模型构造和调参

# %%
data,label,test_id = load_data()
data = get_features(data)
train,test = base_process(data)
# Out:
# G:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4291: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# G:\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
X_train,X_test,y_train,y_test = train_test_split(train,label,test_size=0.25,random_state=33)

# %%
clf1 = lgb.LGBMRegressor(boosting_type='gbdt',num_leaves=31,max_depth=-1,
                n_estimators=2000,subsample=0.8,
                subsample_freq=1,colsample_bytree=0.7,
                random_state=2019,n_jobs=-1)

# %%
clf2 = lgb.LGBMRegressor(boosting_type='gbdt',num_leaves=31,max_depth=-1,
                n_estimators=2000,subsample=0.8,
                subsample_freq=1,colsample_bytree=0.7,
                random_state=2018,n_jobs=-1)

# %%
clf3 = XGBRegressor(n_estimators=2000,silent=True,
            objective='reg:linear',booster='gbtree',n_jobs=-1,gamma=0,
            subsample=0.8,colsample_bytree=0.7,colsample_bylevel=1,
            scale_pos_weight=1,base_score=0.5,random_state=2017)

# %%
clf4 = XGBRegressor(max_depth=4,learning_rate=0.03,n_estimators=2000,silent=True,
            objective='reg:linear',booster='gbtree',n_jobs=-1,gamma=0,
            subsample=0.8,colsample_bytree=0.7,colsample_bylevel=1,
            scale_pos_weight=1,base_score=0.5,random_state=2016)

# %%
kf = StratifiedKFold(n_splits=10,random_state=2015,shuffle=False)
best_score = []
sub_list = []

# %%
param_test ={
   'reg_alpha' :[0.015,0.03,0.05],
   'reg_lambda':[0.8,1.0,1.2]
}

# %%
# grid search 寻找最优超参数
grid_search = GridSearchCV(estimator=clf3,param_grid=param_test,verbose=1,cv=5)

# %%
grid_search.fit(X_train,y_train,eval_metric='mae')
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 14.2min finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=2000,
#        n_jobs=-1, nthread=None, objective='reg:linear', random_state=2017,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.8),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'reg_alpha': [0.015, 0.03, 0.05], 'reg_lambda': [0.8, 1.0, 1.2]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
print(grid_search.score(X_test,y_test))
print(grid_search.best_params_)
# Out:
# 0.7906394026966757
# {'reg_alpha': 0.03, 'reg_lambda': 0.8}

# %%
for i,(train_index,val_index) in enumerate(kf.split(train,label)):
        X_train = train.loc[train_index,:]
        y_train = label[train_index]
        X_val = train.loc[val_index,:]
        y_val = label[val_index]
        
        clf1.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_val,y_val)],
                 eval_metric='mae',early_stopping_rounds=110,verbose=200)
        pred_val1 = clf1.predict(X_val,num_iteration=clf1.best_iteration_)
        val1_mae = mean_absolute_error(y_val,np.round(pred_val1))
        pred_test1 = clf1.predict(test,num_iteration = clf1.best_iteration_)
        
        clf2.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_val,y_val)],
                 eval_metric='rmse',early_stopping_rounds=110,verbose=200)
        pred_val2 = clf2.predict(X_val,num_iteration = clf2.best_iteration_)
        val2_mae = mean_absolute_error(y_val,np.round(pred_val2))
        pred_test2 = clf2.predict(test,num_iteration = clf2.best_iteration_)
        
        clf3.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_val,y_val)],
                 eval_metric='mae',early_stopping_rounds=100,verbose=200)
        pred_val3 = clf3.predict(X_val,ntree_limit=clf3.best_ntree_limit)
        val3_mae = mean_absolute_error(y_val,np.round(pred_val3))
        pred_test3 = clf3.predict(test,ntree_limit=clf3.best_ntree_limit)
        
        clf4.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_val,y_val)],
                 eval_metric='rmse',early_stopping_rounds=100,verbose=200)
        pred_val4 = clf4.predict(X_val,ntree_limit=clf4.best_ntree_limit)
        val4_mae = mean_absolute_error(y_val,np.round(pred_val4))
        pred_test4 = clf4.predict(test,ntree_limit=clf4.best_ntree_limit)
        
        
        pred_val = np.round(pred_val1*0.25 + pred_val2*0.25 + pred_val3*0.25 + pred_val4*0.25)
        vali_mae = mean_absolute_error(y_val,pred_val)
        best_score.append(1/(1+vali_mae))
        
        pred_test = np.round(pred_test1*0.25 + pred_test2*0.25 + pred_test3*0.25 + pred_test4*0.25)
        sub_list.append(pred_test)
        
        print('Round:{:.1f},clf1 score:{:.7f},clf2 score:{:.7f},clf3 score:{:.7f},clf4 score:{:.7f},fusion score:{:.7f}\n'.
             format(i+1,1/(1+val1_mae),1/(1+val2_mae),1/(1+val3_mae),1/(1+val4_mae),1/(1+vali_mae)))
# Out:
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 342.63	training's l1: 14.3288	valid_1's l2: 402.545	valid_1's l1: 15.3872
# [400]	training's l2: 316.321	training's l1: 13.8047	valid_1's l2: 394.29	valid_1's l1: 15.2445
# [600]	training's l2: 297.437	training's l1: 13.4037	valid_1's l2: 392.09	valid_1's l1: 15.2057
# [800]	training's l2: 281.672	training's l1: 13.0533	valid_1's l2: 391.425	valid_1's l1: 15.1986
# Early stopping, best iteration is:
# [777]	training's l2: 283.394	training's l1: 13.0929	valid_1's l2: 391.257	valid_1's l1: 15.1953
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.5263	training's l2: 343.226	valid_1's rmse: 20.0361	valid_1's l2: 401.447
# [400]	training's rmse: 17.7942	training's l2: 316.632	valid_1's rmse: 19.8207	valid_1's l2: 392.859
# [600]	training's rmse: 17.2547	training's l2: 297.724	valid_1's rmse: 19.7791	valid_1's l2: 391.212
# [800]	training's rmse: 16.7848	training's l2: 281.731	valid_1's rmse: 19.7501	valid_1's l2: 390.067
# Early stopping, best iteration is:
# [868]	training's rmse: 16.6328	training's l2: 276.651	valid_1's rmse: 19.741	valid_1's l2: 389.709
# [0]	validation_0-mae:586.831	validation_1-mae:585.478
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.6253	validation_1-mae:15.2515
# [400]	validation_0-mae:12.7969	validation_1-mae:15.2317
# Stopping. Best iteration:
# [348]	validation_0-mae:12.9843	validation_1-mae:15.2125
#
# [0]	validation_0-rmse:588.237	validation_1-rmse:587.081
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.5214	validation_1-rmse:19.9449
# [400]	validation_0-rmse:16.4191	validation_1-rmse:19.9125
# Stopping. Best iteration:
# [438]	validation_0-rmse:16.2353	validation_1-rmse:19.8918
#
# Round:1.0,clf1 score:0.0617538,clf2 score:0.0619153,clf3 score:0.0616796,clf4 score:0.0616322,fusion score:0.0619183
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 343.945	training's l1: 14.3455	valid_1's l2: 388.62	valid_1's l1: 15.2125
# [400]	training's l2: 317.835	training's l1: 13.8295	valid_1's l2: 380.2	valid_1's l1: 15.062
# [600]	training's l2: 299.285	training's l1: 13.4364	valid_1's l2: 378.361	valid_1's l1: 15.0419
# [800]	training's l2: 283.451	training's l1: 13.0895	valid_1's l2: 377.744	valid_1's l1: 15.0265
# Early stopping, best iteration is:
# [835]	training's l2: 280.832	training's l1: 13.0317	valid_1's l2: 377.25	valid_1's l1: 15.016
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.542	training's l2: 343.804	valid_1's rmse: 19.705	valid_1's l2: 388.287
# [400]	training's rmse: 17.8196	training's l2: 317.538	valid_1's rmse: 19.4876	valid_1's l2: 379.767
# [600]	training's rmse: 17.2978	training's l2: 299.213	valid_1's rmse: 19.4536	valid_1's l2: 378.444
# [800]	training's rmse: 16.8287	training's l2: 283.204	valid_1's rmse: 19.449	valid_1's l2: 378.264
# Early stopping, best iteration is:
# [707]	training's rmse: 17.0365	training's l2: 290.242	valid_1's rmse: 19.4399	valid_1's l2: 377.91
# [0]	validation_0-mae:586.771	validation_1-mae:585.919
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.6676	validation_1-mae:15.1274
# [400]	validation_0-mae:12.8367	validation_1-mae:15.0534
# Stopping. Best iteration:
# [412]	validation_0-mae:12.7832	validation_1-mae:15.0442
#
# [0]	validation_0-rmse:588.199	validation_1-rmse:587.456
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.5246	validation_1-rmse:19.5419
# [400]	validation_0-rmse:16.4582	validation_1-rmse:19.4483
# [600]	validation_0-rmse:15.5714	validation_1-rmse:19.4045
# Stopping. Best iteration:
# [690]	validation_0-rmse:15.2191	validation_1-rmse:19.3998
#
# Round:2.0,clf1 score:0.0624303,clf2 score:0.0625092,clf3 score:0.0623242,clf4 score:0.0627030,fusion score:0.0626676
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 343.924	training's l1: 14.3642	valid_1's l2: 375.894	valid_1's l1: 14.7674
# [400]	training's l2: 317.981	training's l1: 13.8502	valid_1's l2: 370.776	valid_1's l1: 14.6463
# [600]	training's l2: 299.058	training's l1: 13.4557	valid_1's l2: 368.875	valid_1's l1: 14.6094
# [800]	training's l2: 283.155	training's l1: 13.1008	valid_1's l2: 367.787	valid_1's l1: 14.5909
# Early stopping, best iteration is:
# [780]	training's l2: 284.639	training's l1: 13.1352	valid_1's l2: 367.634	valid_1's l1: 14.5859
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.5513	training's l2: 344.149	valid_1's rmse: 19.404	valid_1's l2: 376.516
# [400]	training's rmse: 17.8262	training's l2: 317.773	valid_1's rmse: 19.2312	valid_1's l2: 369.838
# [600]	training's rmse: 17.2942	training's l2: 299.091	valid_1's rmse: 19.1916	valid_1's l2: 368.317
# [800]	training's rmse: 16.8231	training's l2: 283.017	valid_1's rmse: 19.1814	valid_1's l2: 367.926
# [1000]	training's rmse: 16.4007	training's l2: 268.982	valid_1's rmse: 19.1808	valid_1's l2: 367.904
# Early stopping, best iteration is:
# [901]	training's rmse: 16.6058	training's l2: 275.752	valid_1's rmse: 19.1733	valid_1's l2: 367.615
# [0]	validation_0-mae:586.736	validation_1-mae:586.254
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.669	validation_1-mae:14.6866
# [400]	validation_0-mae:12.8386	validation_1-mae:14.6438
# Stopping. Best iteration:
# [373]	validation_0-mae:12.9401	validation_1-mae:14.6345
#
# [0]	validation_0-rmse:588.168	validation_1-rmse:587.748
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.5419	validation_1-rmse:19.3071
# [400]	validation_0-rmse:16.4503	validation_1-rmse:19.2509
# Stopping. Best iteration:
# [336]	validation_0-rmse:16.7717	validation_1-rmse:19.2464
#
# Round:3.0,clf1 score:0.0641831,clf2 score:0.0641749,clf3 score:0.0639608,clf4 score:0.0640093,fusion score:0.0642997
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 343.827	training's l1: 14.3457	valid_1's l2: 383.155	valid_1's l1: 15.1055
# [400]	training's l2: 317.377	training's l1: 13.8231	valid_1's l2: 376.173	valid_1's l1: 14.9893
# [600]	training's l2: 298.21	training's l1: 13.4214	valid_1's l2: 374.968	valid_1's l1: 14.9655
# Early stopping, best iteration is:
# [651]	training's l2: 294.011	training's l1: 13.3297	valid_1's l2: 374.593	valid_1's l1: 14.9616
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.5367	training's l2: 343.611	valid_1's rmse: 19.6066	valid_1's l2: 384.42
# [400]	training's rmse: 17.7974	training's l2: 316.747	valid_1's rmse: 19.412	valid_1's l2: 376.824
# [600]	training's rmse: 17.2673	training's l2: 298.161	valid_1's rmse: 19.3616	valid_1's l2: 374.873
# Early stopping, best iteration is:
# [619]	training's rmse: 17.2212	training's l2: 296.57	valid_1's rmse: 19.3584	valid_1's l2: 374.749
# [0]	validation_0-mae:586.702	validation_1-mae:586.569
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.6456	validation_1-mae:15.0562
# [400]	validation_0-mae:12.8076	validation_1-mae:15.0106
# Stopping. Best iteration:
# [385]	validation_0-mae:12.8586	validation_1-mae:15.0047
#
# [0]	validation_0-rmse:588.126	validation_1-rmse:588.009
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.5091	validation_1-rmse:19.4138
# Stopping. Best iteration:
# [261]	validation_0-rmse:17.1462	validation_1-rmse:19.3818
# Round:4.0,clf1 score:0.0626391,clf2 score:0.0626757,clf3 score:0.0625000,clf4 score:0.0626578,fusion score:0.0627311
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 344.597	training's l1: 14.3724	valid_1's l2: 375.476	valid_1's l1: 14.8332
# [400]	training's l2: 318.26	training's l1: 13.8499	valid_1's l2: 370.323	valid_1's l1: 14.7471
# [600]	training's l2: 299.687	training's l1: 13.4582	valid_1's l2: 369.044	valid_1's l1: 14.7301
# [800]	training's l2: 283.699	training's l1: 13.1045	valid_1's l2: 368.6	valid_1's l1: 14.7193
# [1000]	training's l2: 269.328	training's l1: 12.7768	valid_1's l2: 368.492	valid_1's l1: 14.72
# Early stopping, best iteration is:
# [916]	training's l2: 275.13	training's l1: 12.91	valid_1's l2: 368.347	valid_1's l1: 14.7158
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.5497	training's l2: 344.09	valid_1's rmse: 19.4009	valid_1's l2: 376.395
# [400]	training's rmse: 17.8228	training's l2: 317.654	valid_1's rmse: 19.2576	valid_1's l2: 370.853
# [600]	training's rmse: 17.281	training's l2: 298.632	valid_1's rmse: 19.218	valid_1's l2: 369.333
# [800]	training's rmse: 16.811	training's l2: 282.609	valid_1's rmse: 19.1957	valid_1's l2: 368.475
# [1000]	training's rmse: 16.3822	training's l2: 268.378	valid_1's rmse: 19.1853	valid_1's l2: 368.076
# Early stopping, best iteration is:
# [896]	training's rmse: 16.5965	training's l2: 275.444	valid_1's rmse: 19.181	valid_1's l2: 367.909
# [0]	validation_0-mae:586.685	validation_1-mae:586.762
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.6539	validation_1-mae:14.7769
# [400]	validation_0-mae:12.8005	validation_1-mae:14.7477
# Stopping. Best iteration:
# [398]	validation_0-mae:12.8073	validation_1-mae:14.7465
#
# [0]	validation_0-rmse:588.122	validation_1-rmse:588.196
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.5115	validation_1-rmse:19.2437
# [400]	validation_0-rmse:16.4606	validation_1-rmse:19.1694
# Stopping. Best iteration:
# [405]	validation_0-rmse:16.4329	validation_1-rmse:19.1665
#
# Round:5.0,clf1 score:0.0636150,clf2 score:0.0637713,clf3 score:0.0635110,clf4 score:0.0637745,fusion score:0.0638518
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 345.879	training's l1: 14.3914	valid_1's l2: 360.203	valid_1's l1: 14.5911
# [400]	training's l2: 319.848	training's l1: 13.8776	valid_1's l2: 353.868	valid_1's l1: 14.4386
# [600]	training's l2: 301.123	training's l1: 13.4918	valid_1's l2: 352.777	valid_1's l1: 14.4006
# [800]	training's l2: 285.376	training's l1: 13.1473	valid_1's l2: 352.191	valid_1's l1: 14.3856
# Early stopping, best iteration is:
# [773]	training's l2: 287.443	training's l1: 13.1934	valid_1's l2: 352.054	valid_1's l1: 14.3845
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.5926	training's l2: 345.684	valid_1's rmse: 18.9894	valid_1's l2: 360.598
# [400]	training's rmse: 17.8698	training's l2: 319.329	valid_1's rmse: 18.8213	valid_1's l2: 354.243
# [600]	training's rmse: 17.3313	training's l2: 300.373	valid_1's rmse: 18.7733	valid_1's l2: 352.436
# [800]	training's rmse: 16.8628	training's l2: 284.356	valid_1's rmse: 18.7612	valid_1's l2: 351.981
# Early stopping, best iteration is:
# [746]	training's rmse: 16.9867	training's l2: 288.548	valid_1's rmse: 18.7592	valid_1's l2: 351.906
# [0]	validation_0-mae:586.673	validation_1-mae:586.853
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.7249	validation_1-mae:14.4788
# [400]	validation_0-mae:12.9002	validation_1-mae:14.3973
# Stopping. Best iteration:
# [442]	validation_0-mae:12.7519	validation_1-mae:14.3928
#
# [0]	validation_0-rmse:588.105	validation_1-rmse:588.261
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.6036	validation_1-rmse:18.8785
# [400]	validation_0-rmse:16.5184	validation_1-rmse:18.8418
# Stopping. Best iteration:
# [359]	validation_0-rmse:16.7242	validation_1-rmse:18.8345
#
# Round:6.0,clf1 score:0.0650079,clf2 score:0.0649986,clf3 score:0.0649418,clf4 score:0.0649114,fusion score:0.0651234
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 345.187	training's l1: 14.3785	valid_1's l2: 359.266	valid_1's l1: 14.7509
# [400]	training's l2: 318.258	training's l1: 13.8456	valid_1's l2: 355.442	valid_1's l1: 14.6483
# Early stopping, best iteration is:
# [414]	training's l2: 316.789	training's l1: 13.8158	valid_1's l2: 355.365	valid_1's l1: 14.645
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.5899	training's l2: 345.583	valid_1's rmse: 18.9898	valid_1's l2: 360.613
# [400]	training's rmse: 17.8423	training's l2: 318.347	valid_1's rmse: 18.8906	valid_1's l2: 356.854
# [600]	training's rmse: 17.2922	training's l2: 299.02	valid_1's rmse: 18.8813	valid_1's l2: 356.502
# Early stopping, best iteration is:
# [558]	training's rmse: 17.4037	training's l2: 302.89	valid_1's rmse: 18.8735	valid_1's l2: 356.21
# [0]	validation_0-mae:586.644	validation_1-mae:587.144
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.6636	validation_1-mae:14.7382
# [400]	validation_0-mae:12.8132	validation_1-mae:14.6905
# [600]	validation_0-mae:12.1276	validation_1-mae:14.6964
# Stopping. Best iteration:
# [533]	validation_0-mae:12.3464	validation_1-mae:14.6786
#
# [0]	validation_0-rmse:588.089	validation_1-rmse:588.536
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.5694	validation_1-rmse:19.0273
# Stopping. Best iteration:
# [232]	validation_0-rmse:17.3696	validation_1-rmse:19.004
#
# Round:7.0,clf1 score:0.0639244,clf2 score:0.0638775,clf3 score:0.0638035,clf4 score:0.0636406,fusion score:0.0639954
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 346.248	training's l1: 14.3903	valid_1's l2: 357.096	valid_1's l1: 14.6553
# [400]	training's l2: 319.099	training's l1: 13.8611	valid_1's l2: 352.541	valid_1's l1: 14.5413
# Early stopping, best iteration is:
# [476]	training's l2: 311.385	training's l1: 13.7046	valid_1's l2: 352.16	valid_1's l1: 14.5283
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.616	training's l2: 346.556	valid_1's rmse: 18.8788	valid_1's l2: 356.411
# [400]	training's rmse: 17.8731	training's l2: 319.449	valid_1's rmse: 18.7514	valid_1's l2: 351.615
# [600]	training's rmse: 17.3309	training's l2: 300.36	valid_1's rmse: 18.7564	valid_1's l2: 351.804
# Early stopping, best iteration is:
# [505]	training's rmse: 17.574	training's l2: 308.845	valid_1's rmse: 18.7485	valid_1's l2: 351.508
# [0]	validation_0-mae:586.63	validation_1-mae:587.247
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.704	validation_1-mae:14.5927
# [400]	validation_0-mae:12.8549	validation_1-mae:14.5374
# Stopping. Best iteration:
# [399]	validation_0-mae:12.8583	validation_1-mae:14.5374
#
# [0]	validation_0-rmse:588.08	validation_1-rmse:588.609
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.591	validation_1-rmse:18.8356
# Stopping. Best iteration:
# [256]	validation_0-rmse:17.238	validation_1-rmse:18.8034
#
# Round:8.0,clf1 score:0.0644099,clf2 score:0.0644503,clf3 score:0.0643905,clf4 score:0.0642026,fusion score:0.0645652
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 345.885	training's l1: 14.3877	valid_1's l2: 365.781	valid_1's l1: 14.7422
# [400]	training's l2: 319.243	training's l1: 13.8683	valid_1's l2: 362.661	valid_1's l1: 14.6599
# [600]	training's l2: 299.76	training's l1: 13.4664	valid_1's l2: 362.043	valid_1's l1: 14.6386
# [800]	training's l2: 283.536	training's l1: 13.1109	valid_1's l2: 361.889	valid_1's l1: 14.6395
# [1000]	training's l2: 268.99	training's l1: 12.7777	valid_1's l2: 361.383	valid_1's l1: 14.6236
# Early stopping, best iteration is:
# [1045]	training's l2: 266.052	training's l1: 12.7084	valid_1's l2: 361.123	valid_1's l1: 14.6162
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.5847	training's l2: 345.392	valid_1's rmse: 19.1078	valid_1's l2: 365.107
# [400]	training's rmse: 17.8425	training's l2: 318.355	valid_1's rmse: 19.0197	valid_1's l2: 361.749
# Early stopping, best iteration is:
# [439]	training's rmse: 17.7276	training's l2: 314.267	valid_1's rmse: 19.0094	valid_1's l2: 361.357
# [0]	validation_0-mae:586.622	validation_1-mae:587.3
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.7148	validation_1-mae:14.6725
# [400]	validation_0-mae:12.8825	validation_1-mae:14.6441
# Stopping. Best iteration:
# [362]	validation_0-mae:13.0176	validation_1-mae:14.6331
#
# [0]	validation_0-rmse:588.068	validation_1-rmse:588.644
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.5678	validation_1-rmse:19.0464
# [400]	validation_0-rmse:16.4612	validation_1-rmse:19.0055
# Stopping. Best iteration:
# [404]	validation_0-rmse:16.4399	validation_1-rmse:19.0039
#
# Round:9.0,clf1 score:0.0640359,clf2 score:0.0639833,clf3 score:0.0639933,clf4 score:0.0641314,fusion score:0.0642490
#
# Training until validation scores don't improve for 110 rounds.
# [200]	training's l2: 344.698	training's l1: 14.3769	valid_1's l2: 370.524	valid_1's l1: 14.7346
# [400]	training's l2: 318.035	training's l1: 13.8526	valid_1's l2: 365.2	valid_1's l1: 14.5965
# [600]	training's l2: 299.219	training's l1: 13.4607	valid_1's l2: 364.698	valid_1's l1: 14.5664
# Early stopping, best iteration is:
# [583]	training's l2: 300.68	training's l1: 13.4909	valid_1's l2: 364.476	valid_1's l1: 14.5644
# Training until validation scores don't improve for 110 rounds.
# [200]	training's rmse: 18.5673	training's l2: 344.744	valid_1's rmse: 19.2547	valid_1's l2: 370.743
# [400]	training's rmse: 17.8306	training's l2: 317.93	valid_1's rmse: 19.1203	valid_1's l2: 365.585
# [600]	training's rmse: 17.2974	training's l2: 299.2	valid_1's rmse: 19.0847	valid_1's l2: 364.226
# Early stopping, best iteration is:
# [666]	training's rmse: 17.1393	training's l2: 293.754	valid_1's rmse: 19.0792	valid_1's l2: 364.017
# [0]	validation_0-mae:586.609	validation_1-mae:587.455
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 100 rounds.
# [200]	validation_0-mae:13.7095	validation_1-mae:14.7062
# [400]	validation_0-mae:12.8733	validation_1-mae:14.6389
# Stopping. Best iteration:
# [450]	validation_0-mae:12.6781	validation_1-mae:14.6273
#
# [0]	validation_0-rmse:588.059	validation_1-rmse:588.774
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [200]	validation_0-rmse:17.5799	validation_1-rmse:19.2558
# [400]	validation_0-rmse:16.4575	validation_1-rmse:19.2507
# Stopping. Best iteration:
# [347]	validation_0-rmse:16.7186	validation_1-rmse:19.2357
#
# Round:10.0,clf1 score:0.0642420,clf2 score:0.0643292,clf3 score:0.0640013,clf4 score:0.0639795,fusion score:0.0643393

# %%
pred_test = np.mean(np.array(sub_list[2:]),axis=0)

# %%
pred_test = pred_test.astype('int64')
result = pd.Series(pred_test,name='score')
submission = pd.concat([pd.Series(test_id,name='id'),result],axis=1,)

# %%
submission.to_csv('G:/Jupyter_program/Algorithm/DCIC/submit_v2.csv',index=False)

# %%
importance_features = []
for i in range(0,55):
    importance_features.append((clf1.feature_importances_[i],X_train.columns[i]))

# %%
importance_features.sort()

# %%
importance_features
# Out:
# [(1, '是否去过高档商场'),
#  (2, '当月是否到过福州山姆会员店'),
#  (4, '当月是否逛过福州仓山万达'),
#  (4, '是否商场_电影'),
#  (5, '是否大学生客户'),
#  (6, '是否商场_体育馆'),
#  (7, '当月飞机类应用使用次数'),
#  (9, '是否商场_旅游'),
#  (11, '是否黑名单客户'),
#  (11, '用户实名制是否通过核实'),
#  (12, '是否商场_旅游_体育馆'),
#  (16, '是否商场_电影_体育馆'),
#  (18, '是否商场_电影_旅游'),
#  (19, '当月火车类应用使用次数'),
#  (22, '当月是否看电影'),
#  (22, '是否体育馆_旅游'),
#  (23, '商场_旅游'),
#  (23, '当月是否体育场馆消费'),
#  (24, '当月物流快递类应用使用次数'),
#  (25, '商场_体育馆'),
#  (26, '是否体育馆_电影_旅游'),
#  (27, '商场_电影'),
#  (29, '体育馆_旅游'),
#  (31, '是否电影_体育馆'),
#  (31, '是否经常逛商场的人'),
#  (31, '电影_体育馆'),
#  (34, '当月是否景点游览'),
#  (35, '电影_旅游'),
#  (36, '是否电影_旅游'),
#  (44, '用户最近一次缴费距今时长（月）'),
#  (60, '是否不良记录'),
#  (94, '缴费用户当前是否欠费缴费'),
#  (118, '是否4G不健康客户'),
#  (239, '当月旅游资讯类应用使用次数'),
#  (271, '缴费用户最近一次缴费金额（元）'),
#  (303, '用户话费敏感度'),
#  (341, '用户当月账户余额（元）'),
#  (495, '是否积极缴费'),
#  (496, '当月余额是否够用'),
#  (535, '近三个月月均商场出现次数'),
#  (568, '最近一次交费是否超过平均消费额'),
#  (577, '是否有可能超额消费'),
#  (638, '缴费金额能否覆盖当月账单'),
#  (700, '当月金融理财类应用使用总次数'),
#  (701, '当月网购类应用使用次数'),
#  (759, '用户账单当月总费用（元）'),
#  (817, '近半年账单'),
#  (863, '当月视频播放类应用使用次数'),
#  (960, '网龄年龄差'),
#  (1014, '相对网龄'),
#  (1098, '当月通话交往圈人数'),
#  (1216, '用户年龄'),
#  (1247, '用户近6个月平均消费值（元）'),
#  (1263, '当月账单是否超过平均消费额'),
#  (1403, '用户网龄（月）')]

# %%
len(importance_features)
# Out:
# 55
